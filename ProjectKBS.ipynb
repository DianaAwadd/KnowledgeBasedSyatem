# %%
from experta import *

# %%
class food(Fact):
    pass

# %%
StrawberryCheesecake = {"Calories" : 374 , "Fat": 22.68, "Carbs" : 36.11,"Protein":7.59 ,"Cholesterol" :0.062, "Sodium" :0.36 
                    ,"Calcium" :0.075,"Iron" :0.00204,"Potassium":0.186,"VitaminA":0.000198,"VitaminC": 0.022};
ChickenBiryani = {"Calories" : 350 , "Fat": 6, "Carbs" : 59,"Protein":17 ,"Cholesterol" :0.035, "Sodium" :0.86 };
ChickenGyroSandwich = {"Calories" : 519 , "Fat": 6.32, "Carbs" : 77.09,"Protein":35.89 ,"Cholesterol" :0.077, "Sodium" :1.11 
                   ,"Calcium" :0.156,"Iron" :0.0034,"Potassium":0.694,"VitaminA":0.000047,"VitaminC": 0.0133};
GyroSandwich = {"Calories" : 593 , "Fat": 12.21, "Carbs" : 74.02,"Protein":44.15 ,"Cholesterol" :0.082, "Sodium" :0.874 
            ,"Calcium" :0.179,"Iron" :0.0566,"Potassium":0.8,"VitaminA":0.000038,"VitaminC": 0.0117};
LambGyroSandwich = {"Calories" : 557 , "Fat": 11.03, "Carbs" : 77.09,"Protein":34.99 ,"Cholesterol" :0.079, "Sodium" :1.104 
                ,"Calcium" :0.161,"Iron" :0.0414,"Potassium":0.736,"VitaminA":0.000032,"VitaminC": 0.0133};
LadooRoundBall = {"Calories" : 246 , "Fat": 14.89, "Carbs" : 25.86,"Protein":3.55 ,"Cholesterol" :0, "Sodium" :0.0006 
                ,"Calcium" :0.019,"Iron" :0.0104,"Potassium":0.129,"VitaminA":0.000001,"VitaminC": 0.0005};
LemonMeringuePie = {"Calories" : 362 , "Fat": 16.38, "Carbs" : 49.66,"Protein":4.83 ,"Cholesterol" :0.067, "Sodium" :0.307 
                ,"Calcium" :0.015,"Iron" :0.0127,"Potassium":0.083,"VitaminA":0.000055,"VitaminC": 0.0042};
UdonNoodles = {"Calories" : 207 , "Fat": 2.4, "Carbs" : 37.8,"Protein":7.3 };
ItalianBeef = {"Calories" : 140 , "Fat": 7, "Carbs" : 0,"Protein":18 ,"Cholesterol" :0.45, "Sodium" :0.23};
OrganicYellowPopCorn = {"Calories" : 110 , "Fat": 1, "Carbs" : 26,"Protein":4 };
RedVelvetCake = {"Calories" : 293 , "Fat": 13.74, "Carbs" : 37.45,"Protein":5.45 ,"Cholesterol" :0.043, "Sodium" :0.249 
                ,"Calcium" :0.003,"Iron" :0.0076,"Potassium":0.085,"VitaminA":0.000059,"VitaminC": 0.0001};
ChickenBreast = {"Calories" : 164 , "Fat": 6.48, "Carbs" : 0,"Protein":24.82 ,"Cholesterol" :0.07, "Sodium" :0.33 
                ,"Calcium" :0.012,"Iron" :0.0089,"Potassium":0.204,"VitaminA":0.000024,"VitaminC": 0.0};
ApplePie = {"Calories" : 411 , "Fat": 2.09, "Carbs" :57.5,"Protein":3.72 ,"Cholesterol" :0, "Sodium" :0.327 
                ,"Calcium" :0.011,"Iron" :0.00174,"Potassium":0.122,"VitaminA":0.000017,"VitaminC": 0.0026};
Bacon = {"Calories" : 27 , "Fat": 19.38, "Carbs" :0.07,"Protein":1.85,"Cholesterol" :0.006, "Sodium": 0.116
                ,"Calcium" :0.001,"Iron" :0.00007,"Potassium":0.028,"VitaminA":0.000001,"VitaminC": 0.0};
Hummus = {"Calories" : 27 , "Fat": 1.29, "Carbs" :3.02,"Protein":0.73 ,"Cholesterol" :0.0, "Sodium" :0.036
              ,"Calcium" :0.007,"Iron" :0.00024,"Potassium":0.026,"VitaminA":0.0,"VitaminC": 0.0012};
Tiramisu = {"Calories" : 492 , "Fat": 31.67, "Carbs" :42.47,"Protein":8.3 ,"Cholesterol" :0.291, "Sodium" :0.148
                  ,"Calcium" :0.087,"Iron" :0.00224,"Potassium":0.224,"VitaminA":0.000261,"VitaminC": 0.0012};
Okonomiyaki  = {"Calories" : 526 , "Fat": 21.45, "Carbs" :61.31,"Protein":20.66 ,"Cholesterol" :0.183, "Sodium" :0.831
                  ,"Calcium" :0.063,"Iron" :0.00226,"Potassium":0.376,"VitaminA":0.000083,"VitaminC": 0.0177};
OrangeSoda   = {"Calories" : 160 , "Fat": 0, "Carbs" : 44 ,"Protein":0 ,"Cholesterol" :0, "Sodium" :0.055};
FalafelPitaSandwich = {"Calories" : 420 , "Fat": 15, "Carbs" :66,"Protein":13 ,"Cholesterol" :0, "Sodium" :1.27};
GrilledCheeseSandwich = {"Calories" : 291 , "Fat": 15.77, "Carbs" :27.85,"Protein":9.16 ,"Cholesterol" :0.022, "Sodium" :0.764
                  ,"Calcium" :0.235,"Iron" :0.00206,"Potassium":0.129,"VitaminA":0.000129,"VitaminC": 0};
Guacamole  = {"Calories" : 23 , "Fat": 2.08, "Carbs" :1.24,"Protein":0.29 ,"Cholesterol" :0, "Sodium" :0.022
                  ,"Calcium" :0.002,"Iron" :0.00008,"Potassium":0.069,"VitaminA":0.000001,"VitaminC": 0.0015};
EmuDrum = {"Calories" : 435 , "Fat": 2.03, "Carbs" :0,"Protein":97.4,"Cholesterol" :0.329, "Sodium" :0.422
                  ,"Calcium" :0.019,"Iron" :0.018999,"Potassium":1.350,"VitaminA":0,"VitaminC": 0};
CrackerMix = {"Calories" : 140 , "Fat": 6, "Carbs" :18,"Protein":5,"Cholesterol" :0, "Sodium" :0.180
                  ,"Calcium" :0,"Iron" :0.0002,"Potassium":0.160,"VitaminA":0,"VitaminC": 0};
Bhatura = {"Calories" : 230 , "Fat":9, "Carbs" :32,"Protein":5,"Cholesterol" :0, "Sodium" :0.105};
HuevosRancheros = {"Calories" : 140 , "Fat":7.86, "Carbs" :10.07,"Protein":8.13 ,"Cholesterol" :0.216, "Sodium" :0.459
                  ,"Calcium" :0.054,"Iron" :0.00138,"Potassium":0.281,"VitaminA":0.000081,"VitaminC": 0.0012};
BananaCakeWithIcing = {"Calories" : 323 , "Fat":7.85, "Carbs" :61.06,"Protein":3.74 ,"Cholesterol" :0.032, "Sodium" :0.285
                  ,"Calcium" :0.025,"Iron" :0.00114,"Potassium":0.163,"VitaminA":0.000082,"VitaminC": 0.0028};
ChickenPotPie = {"Calories" : 287 , "Fat":18.2, "Carbs" :20.12,"Protein":10.82 ,"Cholesterol" :0.03832, "Sodium" :0.373
                  ,"Calcium" :0.05,"Iron" :0.00171,"Potassium":0.195,"VitaminA":0.000093,"VitaminC": 0.0061};
LasagnaWithMeat = {"Calories" : 336 , "Fat":12.38, "Carbs" :35.43,"Protein":20.52 ,"Cholesterol" :0.049, "Sodium" :0.744
                  ,"Calcium" :0.247,"Iron" :0.00268,"Potassium":0.391,"VitaminA":0.000074,"VitaminC": 0.0072};
Lamb = {"Calories" : 248 , "Fat":17.66, "Carbs" :0,"Protein":20.68 ,"Cholesterol" :0.082, "Sodium" :0.335
                  ,"Calcium" :0.014,"Iron" :0.00159,"Potassium":0.261,"VitaminA":0,"VitaminC": 0};
LambKebab = {"Calories" : 574 , "Fat":10.49, "Carbs" :79.14,"Protein":38.19,"Cholesterol" :0.084, "Sodium" :1.075
                  ,"Calcium" :0.162,"Iron" :0.00456,"Potassium":0.763,"VitaminA":0.000034,"VitaminC": 0.0215};
KeyLimePie = {"Calories" : 364 , "Fat":16.48, "Carbs" :49.62,"Protein":5.06 ,"Cholesterol" :0.083, "Sodium" :0.309
                  ,"Calcium" :0.016,"Iron" :0.00153,"Potassium":0.063,"VitaminA":0.000028,"VitaminC": 0.0024};
TraditionalDonut = {"Calories" : 220 , "Fat":13, "Carbs" :25,"Protein":3 ,"Cholesterol" :0, "Sodium" :0.08};
PitaBread = {"Calories" : 90 , "Fat":0, "Carbs" :18,"Protein":3 ,"Cholesterol" :0, "Sodium" :0.14};
Kasha = {"Calories" :170, "Fat":1, "Carbs" :35,"Protein":6 ,"Cholesterol" :0, "Sodium" :0.01};
BeefShishKabobWithVegetables = {"Calories" : 176, "Fat":5.15, "Carbs" :8.34,"Protein":23.43 ,"Cholesterol" :0.059, "Sodium" :0.570
                  ,"Calcium" :0.024,"Iron" :0.00242,"Potassium":0.632,"VitaminA":0.000038,"VitaminC": 0.00255};
RicePilaf = {"Calories" : 160, "Fat":0.5, "Carbs" :33,"Protein":5 ,"Cholesterol" :0, "Sodium" :0.3};
PorkKabanos = {"Calories" : 300, "Fat":26, "Carbs" :0,"Protein":16 ,"Cholesterol" :0.06, "Sodium" :0.780};
OrganicRawKombucha = {"Calories" : 60, "Fat":0, "Carbs" :14,"Protein":0 ,"Cholesterol" :20, "Sodium" :14};
PacificKombu = {"Calories" : 10, "Fat":0, "Carbs" :2 , "Protein":0 ,"Cholesterol" :0, "Sodium" :0.11};
MozzarellaSticks = {"Calories" : 160, "Fat":9, "Carbs" :13,"Protein":7 ,"Cholesterol" :0.01, "Sodium" :0.420};
Monkfish = {"Calories" : 65, "Fat":1.29, "Carbs" :0,"Protein":12.31 ,"Cholesterol" :0.021, "Sodium" :0.015
                  ,"Calcium" :0.007,"Iron" :0.00027,"Potassium":0.340,"VitaminA":0.00001,"VitaminC": 0.0008};
MongolianBeef = {"Calories" : 180, "Fat":11, "Carbs" :15,"Protein":11 ,"Cholesterol" :0.025, "Sodium" :0.8};
MontrealSmokedMeat = {"Calories" : 210, "Fat":13, "Carbs" :3,"Protein":19 ,"Cholesterol" :0.07, "Sodium" :0.98};
MacaroniOrNoodlesWithCheese = {"Calories" : 493, "Fat":22.84, "Carbs" :52.15,"Protein":19.29 ,"Cholesterol" :0.041, "Sodium" :0.931
                  ,"Calcium" :0.377,"Iron" :0.00243,"Potassium":0.328,"VitaminA":0.000219,"VitaminC": 0};

# %%
class ExpertDiet(KnowledgeEngine):

    @DefFacts()
    def initialfacts(self):
        yield Fact(start="true")
        yield food('StrawberryCheesecake','ChickenBiryani','ChickenGyroSandwich','GyroSandwich','LambGyroSandwich'
                   ,'LadooRoundBall','LemonMeringuePie','UdonNoodles','ItalianBeef','OrganicYellowPopCorn','RedVelvetCake'
                   ,'ChickenBreast','ApplePie','Bacon','Hummus','Tiramisu','Okonomiyaki','OrangeSoda','FalafelPitaSandwich'
                   ,'GrilledCheeseSandwich','Guacamole','EmuDrum','CrackerMix','Bhatura','HuevosRancheros','BananaCakeWithIcing'
                   ,'ChickenPotPie','LasagnaWithMeat','Lamb','LambKebab','KeyLimePie','TraditionalDonut','PitaBread','Kasha'
                   ,'BeefShishKabobWithVegetables','RicePilaf','Premium6GrainRice','PorkKabanos','OrganicRawKombucha'
                   ,'PacificKombu','MozzarellaSticks','Monkfish','MongolianBeef','MontrealSmokedMeat','MacaroniOrNoodlesWithCheese'
                   )
        
        
    @Rule(Fact(start="true"),salience=81)
    def action1(self):
        self.declare(Fact(FoodFromTheMenu=input("please , Choose food from the menu *_*   ")))
    @Rule(NOT(Fact(suffering=W())),salience=80)
    def ask(self):
        self.declare(Fact(suffering=input('Are You Suffering From Disease  ')))
    @Rule(Fact(suffering='no'),salience=79)
    def healthy(self):
        print("You Are A healthy person So Try To eat vigitables and fruits with meals full of proteins")
    @Rule(Fact(suffering='yes'),NOT(Fact(disease=W())),salience=79)
    def ask_dis(self):
        self.declare(Fact(disease = input("What's the disease you suffering from ")))
        
    @Rule(Fact(FoodFromTheMenu='StrawberryCheesecake'),Fact(suffering='yes'),Fact(disease='diabetes'),salience=78)
    def diab(self):
        if 'Carbs' in StrawberryCheesecake.keys() or 'Fat' in StrawberryCheesecake.keys():
            if StrawberryCheesecake['Carbs'] >20 or StrawberryCheesecake['Fat'] >6:
                print("you can not eat it")
                print("Diabetes patients Can eat fruit and vigitables every Day Also eat beanuts Shoufan and النشويات")
            else :
                print("You Can Eat It")
    @Rule(Fact(FoodFromTheMenu='ChickenBiryani'),Fact(suffering='yes'),Fact(disease='diabetes'),salience=78)
    def chicken(self):
        if 'Carbs' in ChickenBiryani.keys() or 'Fat' in ChickenBiryani.keys():
            if ChickenBiryani['Carbs'] >20 or ChickenBiryani['Fat'] >6:
                print("you can not eat it")
                print("Diabetes patients Can eat fruit and vigitables every Day Also eat beanuts Shoufan and النشويات")
            else :
                print("You Can Eat It")
    @Rule(Fact(FoodFromTheMenu='ChickenGyroSandwich'),Fact(suffering='yes'),Fact(disease='diabetes'),salience=78)
    def chi2(self):
         if 'Carbs' in ChickenGyroSandwich.keys() or 'Fat' in ChickenGyroSandwich.keys():
            if ChickenGyroSandwich['Carbs'] >20 or ChickenGyroSandwich['Fat'] >6:
                print("you can not eat it")
                print("Diabetes patients Can eat fruit and vigitables every Day Also eat beanuts Shoufan and النشويات")
            else :
                print("You Can Eat It")
                
    @Rule(Fact(FoodFromTheMenu='GyroSandwich'),Fact(suffering='yes'),Fact(disease='diabetes'),salience=78)
    def gyro(self):
         if 'Carbs' in GyroSandwich.keys() or 'Fat' in GyroSandwich.keys():
            if GyroSandwich['Carbs'] >20 or GyroSandwich['Fat'] >6:
                print("you can not eat it")
                print("Diabetes patients Can eat fruit and vigitables every Day Also eat beanuts Shoufan and النشويات")
            else :
                print("You Can Eat It")
    @Rule(Fact(FoodFromTheMenu='LambGyroSandwich'),Fact(suffering='yes'),Fact(disease='diabetes'),salience=78)
    def lamb(self):
         if 'Carbs' in LambGyroSandwich.keys() or 'Fat' in LambGyroSandwich.keys():
            if LambGyroSandwich['Carbs'] >20 or LambGyroSandwich['Fat'] >6:
                print("you can not eat it")
                print("Diabetes patients Can eat fruit and vigitables every Day Also eat beanuts Shoufan and النشويات")
            else :
                print("You Can Eat It")         
    @Rule(Fact(FoodFromTheMenu='LadooRoundBall'),Fact(suffering='yes'),Fact(disease='diabetes'),salience=78)
    def ladoo(self):
         if 'Carbs' in LadooRoundBall.keys() or 'Fat' in LadooRoundBall.keys():
            if LadooRoundBall['Carbs'] >20 or LadooRoundBall['Fat'] >6:
                print("you can not eat it")
                print("Diabetes patients Can eat fruit and vigitables every Day Also eat beanuts Shoufan and النشويات")
            else :
                print("You Can Eat It")            
    @Rule(Fact(FoodFromTheMenu='UdonNoodles'),Fact(suffering='yes'),Fact(disease='diabetes'),salience=78)
    def udon(self):
         if 'Carbs' in UdonNoodles.keys() or 'Fat' in UdonNoodles.keys():
            if UdonNoodles['Carbs'] >20 or UdonNoodles['Fat'] >6:
                print("you can not eat it")
                print("Diabetes patients Can eat fruit and vigitables every Day Also eat beanuts Shoufan and النشويات")
            else :
                print("You Can Eat It")
                
    @Rule(Fact(FoodFromTheMenu='ItalianBeef'),Fact(suffering='yes'),Fact(disease='diabetes'),salience=78)
    def italian(self):
         if 'Carbs' in ItalianBeef.keys() or 'Fat' in ItalianBeef.keys():
            if ItalianBeef['Carbs'] >20 or ItalianBeef['Fat'] >6:
                print("you can not eat it")
                print("Diabetes patients Can eat fruit and vigitables every Day Also eat beanuts Shoufan and النشويات")
            else :
                print("You Can Eat It")
    @Rule(Fact(FoodFromTheMenu='OrganicYellowPopCorn'),Fact(suffering='yes'),Fact(disease='diabetes'),salience=78)
    def organic(self):
         if 'Carbs' in OrganicYellowPopCorn.keys() or 'Fat' in OrganicYellowPopCorn.keys():
            if OrganicYellowPopCorn['Carbs'] >20 or OrganicYellowPopCorn['Fat'] >6:
                print("you can not eat it")
                print("Diabetes patients Can eat fruit and vigitables every Day Also eat beanuts Shoufan and النشويات")
            else :
                print("You Can Eat It")
      
    @Rule(Fact(FoodFromTheMenu='RedVelvetCake'),Fact(suffering='yes'),Fact(disease='diabetes'),salience=78)
    def Red(self):
         if 'Carbs' in RedVelvetCake.keys() or 'Fat' in RedVelvetCake.keys():
            if RedVelvetCake['Carbs'] >20 or RedVelvetCake['Fat'] >6:
                print("you can not eat it")
                print("Diabetes patients Can eat fruit and vigitables every Day Also eat beanuts Shoufan and النشويات")
            else :
                print("You Can Eat It")
                
    @Rule(Fact(FoodFromTheMenu='ChickenBreast'),Fact(suffering='yes'),Fact(disease='diabetes'),salience=78)
    def breast(self):
         if 'Carbs' in ChickenBreast.keys() or 'Fat' in ChickenBreast.keys():
            if ChickenBreast['Carbs'] >20 or ChickenBreast['Fat'] >6:
                print("you can not eat it")
                print("Diabetes patients Can eat fruit and vigitables every Day Also eat beanuts Shoufan and النشويات")
            else :
                print("You Can Eat It")
    @Rule(Fact(FoodFromTheMenu='ApplePie'),Fact(suffering='yes'),Fact(disease='diabetes'),salience=78)
    def apple(self):
         if 'Carbs' in ApplePie.keys() or 'Fat' in ApplePie.keys():
            if ApplePie['Carbs'] >20 or ApplePie['Fat'] >6:
                print("you can not eat it")
                print("Diabetes patients Can eat fruit and vigitables every Day Also eat beanuts Shoufan and النشويات")
            else :
                print("You Can Eat It")
    @Rule(Fact(FoodFromTheMenu='Bacon'),Fact(suffering='yes'),Fact(disease='diabetes'),salience=78)
    def bacon(self):
         if 'Carbs' in Bacon.keys() or 'Fat' in Bacon.keys():
            if Bacon['Carbs'] >20 or Bacon['Fat'] >6:
                print("you can not eat it")
                print("Diabetes patients Can eat fruit and vigitables every Day Also eat beanuts Shoufan and النشويات")
            else :
                print("You Can Eat It")
    @Rule(Fact(FoodFromTheMenu='LemonMeringuePie'),Fact(suffering='yes'),Fact(disease='diabetes'),salience=78)
    def lemon(self):
         if 'Carbs' in LemonMeringuePie.keys() or 'Fat' in LemonMeringuePie.keys():
            if LemonMeringuePie['Carbs'] >20 or LemonMeringuePie['Fat'] >6:
                print("you can not eat it")
                print("Diabetes patients Can eat fruit and vigitables every Day Also eat beanuts Shoufan and النشويات")
            else :
                print("You Can Eat It")
                
    @Rule(Fact(FoodFromTheMenu='Tiramisu'),Fact(suffering='yes'),Fact(disease='diabetes'),salience=78)
    def teramisu(self):
         if 'Carbs' in Tiramisu.keys() or 'Fat' in Tiramisu.keys():
            if Tiramisu['Carbs'] >20 or Tiramisu['Fat'] >6:
                print("you can not eat it")
                print("Diabetes patients Can eat fruit and vigitables every Day Also eat beanuts Shoufan and النشويات")
            else :
                print("You Can Eat It")
    
    @Rule(Fact(FoodFromTheMenu='Okonomiyaki'),Fact(suffering='yes'),Fact(disease='diabetes'),salience=78)
    def Okonomiyaki(self):
         if 'Carbs' in Okonomiyaki.keys() or 'Fat' in Okonomiyaki.keys():
            if Okonomiyaki['Carbs'] >20 or Okonomiyaki['Fat'] >6:
                print("you can not eat it")
                print("Diabetes patients Can eat fruit and vigitables every Day Also eat beanuts Shoufan and النشويات")
            else :
                print("You Can Eat It")
     
    @Rule(Fact(FoodFromTheMenu='OrangeSoda'),Fact(suffering='yes'),Fact(disease='diabetes'),salience=78)
    def OrangeSoda(self):
         if 'Carbs' in OrangeSoda.keys() or 'Fat' in OrangeSoda.keys():
            if OrangeSoda['Carbs'] >20 or OrangeSoda['Fat'] >6:
                print("you can not eat it")
                print("Diabetes patients Can eat fruit and vigitables every Day Also eat beanuts Shoufan and النشويات")
            else :
                print("You Can Eat It")
                     
    @Rule(Fact(FoodFromTheMenu='FalafelPitaSandwich'),Fact(suffering='yes'),Fact(disease='diabetes'),salience=78)
    def FalafelPitaSandwich(self):
         if 'Calories' in FalafelPitaSandwich.keys() or 'Fat' in FalafelPitaSandwich.keys():
            if FalafelPitaSandwich['Calories'] >170 or FalafelPitaSandwich['Fat'] >10:
                print("you can not eat it")
                print("Advise for Obesity Patient it's more useful to avoid sugar and fat ,try to eatfruits and vigitables and replace drinks with fats to healthy drinks")
            else :
                print("You Can Eat It")
                
                
    @Rule(Fact(FoodFromTheMenu='StrawberryCheesecake'),Fact(suffering='yes'),Fact(disease='obesity'),salience=78)
    def diab(self):
        if 'Calories' in StrawberryCheesecake.keys() or 'Fat' in StrawberryCheesecake.keys():
            if StrawberryCheesecake['Calories'] >170 or StrawberryCheesecake['Fat'] >10:
                print("you can not eat it")
                print("Advise for Obesity Patient it's more useful to avoid sugar and fat ,try to eatfruits and vigitables and replace drinks with fats to healthy drinks")
            else :
                print("You Can Eat It")
    @Rule(Fact(FoodFromTheMenu='ChickenBiryani'),Fact(suffering='yes'),Fact(disease='obesity'),salience=78)
    def chicken(self):
        if 'Calories' in ChickenBiryani.keys() or 'Fat' in ChickenBiryani.keys():
            if ChickenBiryani['Calories'] >170 or ChickenBiryani['Fat'] >10:
                print("you can not eat it")
                print("Advise for Obesity Patient it's more useful to avoid sugar and fat ,try to eatfruits and vigitables and replace drinks with fats to healthy drinks")
            else :
                print("You Can Eat It")
    @Rule(Fact(FoodFromTheMenu='ChickenGyroSandwich'),Fact(suffering='yes'),Fact(disease='obesity'),salience=78)
    def chi2(self):
         if 'Calories' in ChickenGyroSandwich.keys() or 'Fat' in ChickenGyroSandwich.keys():
            if ChickenGyroSandwich['Calories'] >170 or ChickenGyroSandwich['Fat'] >10:
                print("you can not eat it")
                print("Advise for Obesity Patient it's more useful to avoid sugar and fat ,try to eatfruits and vigitables and replace drinks with fats to healthy drinks")
            else :
                print("You Can Eat It")
                
    @Rule(Fact(FoodFromTheMenu='GyroSandwich'),Fact(suffering='yes'),Fact(disease='obesity'),salience=78)
    def gyro(self):
         if 'Calories' in GyroSandwich.keys() or 'Fat' in GyroSandwich.keys():
            if GyroSandwich['Calories'] >170 or GyroSandwich['Fat'] >10:
                print("you can not eat it")
                print("Advise for Obesity Patient it's more useful to avoid sugar and fat ,try to eatfruits and vigitables and replace drinks with fats to healthy drinks")
            else :
                print("You Can Eat It")
                
    @Rule(Fact(FoodFromTheMenu='LambGyroSandwich'),Fact(suffering='yes'),Fact(disease='obesity'),salience=78)
    def lamb(self):
         if 'Calories' in LambGyroSandwich.keys() or 'Fat' in LambGyroSandwich.keys():
            if LambGyroSandwich['Calories'] >170 or LambGyroSandwich['Fat'] >10:
                print("you can not eat it")
                print("Advise for Obesity Patient it's more useful to avoid sugar and fat ,try to eatfruits and vigitables and replace drinks with fats to healthy drinks")
            else :
                print("You Can Eat It")         
    @Rule(Fact(FoodFromTheMenu='LadooRoundBall'),Fact(suffering='yes'),Fact(disease='obesity'),salience=78)
    def ladoo(self):
         if 'Calories' in LadooRoundBall.keys() or 'Fat' in LadooRoundBall.keys():
            if LadooRoundBall['Calories'] >170 or LadooRoundBall['Fat'] >10:
                print("you can not eat it")
                print("Advise for Obesity Patient it's more useful to avoid sugar and fat ,try to eatfruits and vigitables and replace drinks with fats to healthy drinks")
            else :
                print("You Can Eat It")            
    @Rule(Fact(FoodFromTheMenu='UdonNoodles'),Fact(suffering='yes'),Fact(disease='obesity'),salience=78)
    def udon(self):
         if 'Calories' in UdonNoodles.keys() or 'Fat' in UdonNoodles.keys():
            if UdonNoodles['Calories'] >170 or UdonNoodles['Fat'] >10:
                print("you can not eat it")
                print("Advise for Obesity Patient it's more useful to avoid sugar and fat ,try to eatfruits and vigitables and replace drinks with fats to healthy drinks")
            else :
                print("You Can Eat It")
                
    @Rule(Fact(FoodFromTheMenu='ItalianBeef'),Fact(suffering='yes'),Fact(disease='obesity'),salience=78)
    def italian(self):
         if 'Calories' in ItalianBeef.keys() or 'Fat' in ItalianBeef.keys():
            if ItalianBeef['Calories'] >170 or ItalianBeef['Fat'] >10:
                print("you can not eat it")
                print("Advise for Obesity Patient it's more useful to avoid sugar and fat ,try to eatfruits and vigitables and replace drinks with fats to healthy drinks")
            else :
                print("You Can Eat It")
    @Rule(Fact(FoodFromTheMenu='OrganicYellowPopCorn'),Fact(suffering='yes'),Fact(disease='obesity'),salience=78)
    def organic(self):
         if 'Calories' in OrganicYellowPopCorn.keys() or 'Fat' in OrganicYellowPopCorn.keys():
            if OrganicYellowPopCorn['Calories'] >170 or OrganicYellowPopCorn['Fat'] >10:
                print("you can not eat it")
                print("Advise for Obesity Patient it's more useful to avoid sugar and fat ,try to eatfruits and vigitables and replace drinks with fats to healthy drinks")
            else :
                print("You Can Eat It")
      
    @Rule(Fact(FoodFromTheMenu='RedVelvetCake'),Fact(suffering='yes'),Fact(disease='obesity'),salience=78)
    def Red(self):
         if 'Calories' in RedVelvetCake.keys() or 'Fat' in RedVelvetCake.keys():
            if RedVelvetCake['Calories'] >170 or RedVelvetCake['Fat'] >10:
                print("you can not eat it")
                print("Advise for Obesity Patient it's more useful to avoid sugar and fat ,try to eatfruits and vigitables and replace drinks with fats to healthy drinks")
            else :
                print("You Can Eat It")
                
    @Rule(Fact(FoodFromTheMenu='ChickenBreast'),Fact(suffering='yes'),Fact(disease='obesity'),salience=78)
    def breast(self):
         if 'Calories' in ChickenBreast.keys() or 'Fat' in ChickenBreast.keys():
            if ChickenBreast['Calories'] >170 or ChickenBreast['Fat'] >10:
                print("you can not eat it")
                print("Advise for Obesity Patient it's more useful to avoid sugar and fat ,try to eatfruits and vigitables and replace drinks with fats to healthy drinks")
            else :
                print("You Can Eat It")
    @Rule(Fact(FoodFromTheMenu='ApplePie'),Fact(suffering='yes'),Fact(disease='obesity'),salience=78)
    def apple(self):
         if 'Calories' in ApplePie.keys() or 'Fat' in ApplePie.keys():
            if ApplePie['Calories'] >170 or ApplePie['Fat'] >10:
                print("you can not eat it")
                print("Advise for Obesity Patient it's more useful to avoid sugar and fat ,try to eatfruits and vigitables and replace drinks with fats to healthy drinks")
            else :
                print("You Can Eat It")
    @Rule(Fact(FoodFromTheMenu='Bacon'),Fact(suffering='yes'),Fact(disease='obesity'),salience=78)
    def bacon(self):
         if 'Calories' in Bacon.keys() or 'Fat' in Bacon.keys():
            if Bacon['Calories'] >170 or Bacon['Fat'] >10:
                print("you can not eat it")
                print("Advise for Obesity Patient it's more useful to avoid sugar and fat ,try to eatfruits and vigitables and replace drinks with fats to healthy drinks")
            else :
                print("You Can Eat It")
    @Rule(Fact(FoodFromTheMenu='LemonMeringuePie'),Fact(suffering='yes'),Fact(disease='obesity'),salience=78)
    def lemon(self):
         if 'Calories' in LemonMeringuePie.keys() or 'Fat' in LemonMeringuePie.keys():
            if LemonMeringuePie['Calories'] >170 or LemonMeringuePie['Fat'] >10:
                print("you can not eat it")
                print("Advise for Obesity Patient it's more useful to avoid sugar and fat ,try to eatfruits and vigitables and replace drinks with fats to healthy drinks")
            else :
                print("You Can Eat It")
                
    @Rule(Fact(FoodFromTheMenu='Tiramisu'),Fact(suffering='yes'),Fact(disease='obesity'),salience=78)
    def teramisu(self):
         if 'Calories' in Tiramisu.keys() or 'Fat' in Tiramisu.keys():
            if Tiramisu['Calories'] >170 or Tiramisu['Fat'] >10:
                print("you can not eat it")
                print("Advise for Obesity Patient it's more useful to avoid sugar and fat ,try to eatfruits and vigitables and replace drinks with fats to healthy drinks")
            else :
                print("You Can Eat It")
    
    @Rule(Fact(FoodFromTheMenu='Okonomiyaki'),Fact(suffering='yes'),Fact(disease='obesity'),salience=78)
    def Okonomiyaki(self):
         if 'Calories' in Okonomiyaki.keys() or 'Fat' in Okonomiyaki.keys():
            if Okonomiyaki['Calories'] >170 or Okonomiyaki['Fat'] >10:
                print("you can not eat it")
                print("Advise for Obesity Patient it's more useful to avoid sugar and fat ,try to eatfruits and vigitables and replace drinks with fats to healthy drinks")
            else :
                print("You Can Eat It")
     
    @Rule(Fact(FoodFromTheMenu='OrangeSoda'),Fact(suffering='yes'),Fact(disease='obesity'),salience=78)
    def OrangeSoda(self):
         if 'Calories' in OrangeSoda.keys() or 'Fat' in OrangeSoda.keys():
            if OrangeSoda['Calories'] >170 or OrangeSoda['Fat'] >10:
                print("you can not eat it")
                print("Advise for Obesity Patient it's more useful to avoid sugar and fat ,try to eatfruits and vigitables and replace drinks with fats to healthy drinks")
            else :
                print("You Can Eat It")
    @Rule(Fact(FoodFromTheMenu='FalafelPitaSandwich'),Fact(suffering='yes'),Fact(disease='obesity'),salience=78)
    def FalafelPitaSandwich(self):
         if 'Calories' in FalafelPitaSandwich.keys() or 'Fat' in FalafelPitaSandwich.keys():
            if FalafelPitaSandwich['Calories'] >170 or FalafelPitaSandwich['Fat'] >10:
                print("you can not eat it")
                print("Advise for Obesity Patient it's more useful to avoid sugar and fat ,try to eatfruits and vigitables and replace drinks with fats to healthy drinks")
            else :
                print("You Can Eat It")
                
                
    @Rule(OR(Fact(FoodFromTheMenu='StrawberryCheesecake'),Fact(FoodFromTheMenu='ChickenBiryani'),Fact(FoodFromTheMenu='ChickenGyroSandwich'),
            Fact(FoodFromTheMenu='GyroSandwich'),Fact(FoodFromTheMenu='FalafelPitaSandwich'),Fact(FoodFromTheMenu='OrangeSoda'),Fact(FoodFromTheMenu='Okonomiyaki')
            ,Fact(FoodFromTheMenu='Tiramisu'),Fact(FoodFromTheMenu='LemonMeringuePie'),Fact(FoodFromTheMenu='ApplePie'),Fact(FoodFromTheMenu='ChickenBreast')
            ),Fact(disease='goat'))
    def goat(self):
        print("You Can Eat it")
        
    @Rule(OR(Fact(FoodFromTheMenu='LambKebab'),Fact(FoodFromTheMenu='ItalianBeef'),Fact(FoodFromTheMenu='BeefShishKabobWithVegetables'),
            Fact(FoodFromTheMenu='Monkfish'),Fact(FoodFromTheMenu='MongolianBeef')),Fact(disease='goat'))
    def goat(self):
        print("You Can not Eat it")
        print("Goat patients should avoid red meet and fishes and try to eat carbohidrats and milks with low fats")
        
        
        
    @Rule(Fact(FoodFromTheMenu='StrawberryCheesecake'),Fact(suffering='yes'),Fact(disease='weakBones'),salience=78)
    def diab(self):
        if 'Calcium' in StrawberryCheesecake.keys() or 'Potassium' in StrawberryCheesecake.keys():
            if StrawberryCheesecake['Calcium'] >0.3 or StrawberryCheesecake['Potassium'] >0.3:
                print("you can not eat it")
                print("WeakBones patients should eat beanits and Smsom,Also they Should drink milk and potato")
            else :
                print("You Can Eat It")
    @Rule(Fact(FoodFromTheMenu='ChickenBiryani'),Fact(suffering='yes'),Fact(disease='weakBones'),salience=78)
    def chicken(self):
        if 'Calcium' in ChickenBiryani.keys() or 'Potassium' in ChickenBiryani.keys():
            if ChickenBiryani['Calcium'] >0.3 or ChickenBiryani['Potassium'] >0.3:
                print("you can not eat it")
                print("WeakBones patients should eat beanits and Smsom,Also they Should drink milk and potato")
            else :
                print("You Can Eat It")
    @Rule(Fact(FoodFromTheMenu='ChickenGyroSandwich'),Fact(suffering='yes'),Fact(disease='weakBones'),salience=78)
    def chi2(self):
         if 'Calcium' in ChickenGyroSandwich.keys() or 'Potassium' in ChickenGyroSandwich.keys():
            if ChickenGyroSandwich['Calcium'] >0.3 or ChickenGyroSandwich['Potassium'] >0.3:
                print("you can not eat it")
                print("WeakBones patients should eat beanits and Smsom,Also they Should drink milk and potato")
            else :
                print("You Can Eat It")
                
    @Rule(Fact(FoodFromTheMenu='GyroSandwich'),Fact(suffering='yes'),Fact(disease='weakBones'),salience=78)
    def gyro(self):
         if 'Calcium' in GyroSandwich.keys() or 'Potassium' in GyroSandwich.keys():
            if GyroSandwich['Calcium'] >0.3 or GyroSandwich['Potassium'] >0.3:
                print("you can not eat it")
                print("WeakBones patients should eat beanits and Smsom,Also they Should drink milk and potato")
            else :
                print("You Can Eat It")
    @Rule(Fact(FoodFromTheMenu='LambGyroSandwich'),Fact(suffering='yes'),Fact(disease='weakBones'),salience=78)
    def lamb(self):
         if 'Calcium' in LambGyroSandwich.keys() or 'Potassium' in LambGyroSandwich.keys():
            if LambGyroSandwich['Calcium'] >0.3 or LambGyroSandwich['Potassium'] >0.3:
                print("you can not eat it")
                print("WeakBones patients should eat beanits and Smsom,Also they Should drink milk and potato")
            else :
                print("You Can Eat It")         
    @Rule(Fact(FoodFromTheMenu='LadooRoundBall'),Fact(suffering='yes'),Fact(disease='weakBones'),salience=78)
    def ladoo(self):
         if 'Calcium' in LadooRoundBall.keys() or 'Potassium' in LadooRoundBall.keys():
            if LadooRoundBall['Calcium'] >0.3 or LadooRoundBall['Potassium'] >0.3:
                print("you can not eat it")
                print("WeakBones patients should eat beanits and Smsom,Also they Should drink milk and potato")
            else :
                print("You Can Eat It")            
    @Rule(Fact(FoodFromTheMenu='UdonNoodles'),Fact(suffering='yes'),Fact(disease='weakBones'),salience=78)
    def udon(self):
         if 'Calcium' in UdonNoodles.keys() or 'Potassium' in UdonNoodles.keys():
            if UdonNoodles['Calcium'] >0.3 or UdonNoodles['Potassium'] >0.3:
                print("you can not eat it")
                print("WeakBones patients should eat beanits and Smsom,Also they Should drink milk and potato")
            else :
                print("You Can Eat It")
                
    @Rule(Fact(FoodFromTheMenu='ItalianBeef'),Fact(suffering='yes'),Fact(disease='weakBones'),salience=78)
    def italian(self):
         if 'Calcium' in ItalianBeef.keys() or 'Potassium' in ItalianBeef.keys():
            if ItalianBeef['Calcium'] >0.3 or ItalianBeef['Potassium'] >0.3:
                print("you can not eat it")
                print("WeakBones patients should eat beanits and Smsom,Also they Should drink milk and potato")
            else :
                print("You Can Eat It")
    @Rule(Fact(FoodFromTheMenu='OrganicYellowPopCorn'),Fact(suffering='yes'),Fact(disease='weakBones'),salience=78)
    def organic(self):
         if 'Calcium' in OrganicYellowPopCorn.keys() or 'Potassium' in OrganicYellowPopCorn.keys():
            if OrganicYellowPopCorn['Calcium'] >0.3 or OrganicYellowPopCorn['Potassium'] >0.3:
                print("you can not eat it")
                print("WeakBones patients should eat beanits and Smsom,Also they Should drink milk and potato")
            else :
                print("You Can Eat It")
      
    @Rule(Fact(FoodFromTheMenu='RedVelvetCake'),Fact(suffering='yes'),Fact(disease='weakBones'),salience=78)
    def Red(self):
         if 'Calcium' in RedVelvetCake.keys() or 'Potassium' in RedVelvetCake.keys():
            if RedVelvetCake['Calcium'] >0.3 or RedVelvetCake['Potassium'] >0.3:
                print("you can not eat it")
                print("WeakBones patients should eat beanits and Smsom,Also they Should drink milk and potato")
            else :
                print("You Can Eat It")
                
    @Rule(Fact(FoodFromTheMenu='ChickenBreast'),Fact(suffering='yes'),Fact(disease='weakBones'),salience=78)
    def breast(self):
         if 'Calcium' in ChickenBreast.keys() or 'Potassium' in ChickenBreast.keys():
            if ChickenBreast['Calcium'] >0.3 or ChickenBreast['Potassium'] >0.3:
                print("you can not eat it")
                print("WeakBones patients should eat beanits and Smsom,Also they Should drink milk and potato")
            else :
                print("You Can Eat It")
    @Rule(Fact(FoodFromTheMenu='ApplePie'),Fact(suffering='yes'),Fact(disease='weakBones'),salience=78)
    def apple(self):
         if 'Calcium' in ApplePie.keys() or 'Potassium' in ApplePie.keys():
            if ApplePie['Calcium'] >0.3 or ApplePie['Potassium'] >0.3:
                print("you can not eat it")
                print("WeakBones patients should eat beanits and Smsom,Also they Should drink milk and potato")
            else :
                print("You Can Eat It")
    @Rule(Fact(FoodFromTheMenu='Bacon'),Fact(suffering='yes'),Fact(disease='weakBones'),salience=78)
    def bacon(self):
         if 'Calcium' in Bacon.keys() or 'Potassium' in Bacon.keys():
            if Bacon['Calcium'] >0.3 or Bacon['Potassium'] >0.3:
                print("you can not eat it")
                print("WeakBones patients should eat beanits and Smsom,Also they Should drink milk and potato")
            else :
                print("You Can Eat It")
    @Rule(Fact(FoodFromTheMenu='LemonMeringuePie'),Fact(suffering='yes'),Fact(disease='weakBones'),salience=78)
    def lemon(self):
         if 'Calcium' in LemonMeringuePie.keys() or 'Potassium' in LemonMeringuePie.keys():
            if LemonMeringuePie['Calcium'] >0.3 or LemonMeringuePie['Potassium'] >0.3:
                print("you can not eat it")
                print("WeakBones patients should eat beanits and Smsom,Also they Should drink milk and potato")
            else :
                print("You Can Eat It")
                
    @Rule(Fact(FoodFromTheMenu='Tiramisu'),Fact(suffering='yes'),Fact(disease='weakBones'),salience=78)
    def teramisu(self):
         if 'Calcium' in Tiramisu.keys() or 'Potassium' in Tiramisu.keys():
            if Tiramisu['Calcium'] >0.3 or Tiramisu['Potassium'] >0.3:
                print("you can not eat it")
                print("WeakBones patients should eat beanits and Smsom,Also they Should drink milk and potato")
            else :
                print("You Can Eat It")
    
    @Rule(Fact(FoodFromTheMenu='Okonomiyaki'),Fact(suffering='yes'),Fact(disease='weakBones'),salience=78)
    def Okonomiyaki(self):
         if 'Calcium' in Okonomiyaki.keys() or 'Potassium' in Okonomiyaki.keys():
            if Okonomiyaki['Calcium'] >0.3 or Okonomiyaki['Potassium'] >0.3:
                print("you can not eat it")
                print("WeakBones patients should eat beanits and Smsom,Also they Should drink milk and potato")
            else :
                print("You Can Eat It")
     
    @Rule(Fact(FoodFromTheMenu='OrangeSoda'),Fact(suffering='yes'),Fact(disease='weakBones'),salience=78)
    def OrangeSoda(self):
         if 'Calcium' in OrangeSoda.keys() or 'Potassium' in OrangeSoda.keys():
            if OrangeSoda['Calcium'] >0.3 or OrangeSoda['Potassium'] >0.3:
                print("you can not eat it")
                print("WeakBones patients should eat beanits and Smsom,Also they Should drink milk and potato")
            else :
                print("You Can Eat It")
                     
    @Rule(Fact(FoodFromTheMenu='FalafelPitaSandwich'),Fact(suffering='yes'),Fact(disease='weakBones'),salience=78)
    def FalafelPitaSandwich(self):
         if 'Calcium' in FalafelPitaSandwich.keys() or 'Potassium' in FalafelPitaSandwich.keys():
            if FalafelPitaSandwich['Calcium'] >0.3 or FalafelPitaSandwich['Potassium'] >0.3:
                print("you can not eat it")
                print("WeakBones patients should eat beanits and Smsom,Also they Should drink milk and potato")
            else :
                print("You Can Eat It")
    
    
    @Rule(Fact(start="true"),Fact(FoodFromTheMenu="StrawberryCheesecake"))
    def action2(self):
        for x in StrawberryCheesecake.items():
            print (x[1],'\t',x[0])
            
    @Rule(Fact(start="true"),Fact(FoodFromTheMenu="ChickenBiryani"))
    def action3(self):
        for x in ChickenBiryani.items():
            print (x[1],'\t',x[0])
            
    @Rule(Fact(start="true"),Fact(FoodFromTheMenu="ChickenGyroSandwich"))
    def action4(self):
        for x in ChickenGyroSandwich.items():
            print (x[1],'\t',x[0])
            
    @Rule(Fact(start="true"),Fact(FoodFromTheMenu="GyroSandwich"))
    def action5(self):
        for x in GyroSandwich.items():
            print (x[1],'\t',x[0])
    
    @Rule(Fact(start="true"),Fact(FoodFromTheMenu="LambGyroSandwich"))
    def action6(self):
        for x in LambGyroSandwich.items():
            print (x[1],'\t',x[0])
            
            
    @Rule(Fact(start="true"),Fact(FoodFromTheMenu="LadooRoundBall"))
    def action7(self):
        for x in LadooRoundBall.items():
            print (x[1],'\t',x[0])
            
    @Rule(Fact(start="true"),Fact(FoodFromTheMenu="UdonNoodles"))
    def action8(self):
        for x in UdonNoodles.items():
            print (x[1],'\t',x[0])
            
    @Rule(Fact(start="true"),Fact(FoodFromTheMenu="ItalianBeef"))
    def action9(self):
        for x in ItalianBeef.items():
            print (x[1],'\t',x[0])
    
    @Rule(Fact(start="true"),Fact(FoodFromTheMenu="OrganicYellowPopCorn"))
    def action10(self):
        for x in OrganicYellowPopCorn.items():
            print (x[1],'\t',x[0])
    
    @Rule(Fact(start="true"),Fact(FoodFromTheMenu="RedVelvetCake"))
    def action11(self):
        for x in RedVelvetCake.items():
            print (x[1],'\t',x[0])
            
    @Rule(Fact(start="true"),Fact(FoodFromTheMenu="ChickenBreast"))
    def action12(self):
        for x in ChickenBreast.items():
            print (x[1],'\t',x[0])
            
    @Rule(Fact(start="true"),Fact(FoodFromTheMenu="ApplePie"))
    def action13(self):
        for x in ApplePie.items():
            print (x[1],'\t',x[0])
            
    @Rule(Fact(start="true"),Fact(FoodFromTheMenu="Bacon"))
    def action14(self):
        for x in Bacon.items():
            print (x[1],'\t',x[0])
   
    @Rule(Fact(start="true"),Fact(FoodFromTheMenu="Hummus"))
    def action15(self):
        for x in Hummus.items():
            print (x[1],'\t',x[0])
            
    @Rule(Fact(start="true"),Fact(FoodFromTheMenu="LemonMeringuePie"))
    def action16(self):
        for x in LemonMeringuePie.items():
            print (x[1],'\t',x[0])
            
    @Rule(Fact(start="true"),Fact(FoodFromTheMenu="Tiramisu"))
    def action17(self):
        for x in Tiramisu.items():
            print (x[1],'\t',x[0])
            
    @Rule(Fact(start="true"),Fact(FoodFromTheMenu="Okonomiyaki"))
    def action18(self):
        for x in Okonomiyaki.items():
            print (x[1],'\t',x[0])      
            
    @Rule(Fact(start="true"),Fact(FoodFromTheMenu="OrangeSoda"))
    def action19(self):
        for x in OrangeSoda.items():
            print (x[1],'\t',x[0])
            
    @Rule(Fact(start="true"),Fact(FoodFromTheMenu="FalafelPitaSandwich"))
    def action20(self):
        for x in FalafelPitaSandwich.items():
            print (x[1],'\t',x[0])
            
    @Rule(Fact(start="true"),Fact(FoodFromTheMenu="GrilledCheeseSandwich"))
    def action21(self):
        for x in GrilledCheeseSandwich.items():
            print (x[1],'\t',x[0])
            
    @Rule(Fact(start="true"),Fact(FoodFromTheMenu="Guacamole"))
    def action22(self):
        for x in Guacamole.items():
            print (x[1],'\t',x[0])
            
    @Rule(Fact(start="true"),Fact(FoodFromTheMenu="EmuDrum"))
    def action23(self):
        for x in EmuDrum.items():
            print (x[1],'\t',x[0])
            
    @Rule(Fact(start="true"),Fact(FoodFromTheMenu="CrackerMix"))
    def action24(self):
        for x in CrackerMix.items():
            print (x[1],'\t',x[0])
            
    @Rule(Fact(start="true"),Fact(FoodFromTheMenu="Bhatura"))
    def action25(self):
        for x in Bhatura.items():
            print (x[1],'\t',x[0])
           
    @Rule(Fact(start="true"),Fact(FoodFromTheMenu="HuevosRancheros"))
    def action26(self):
        for x in HuevosRancheros.items():
            print (x[1],'\t',x[0])
           
    @Rule(Fact(start="true"),Fact(FoodFromTheMenu="BananaCakeWithIcing"))
    def action27(self):
        for x in BananaCakeWithIcing.items():
            print (x[1],'\t',x[0])
           
    @Rule(Fact(start="true"),Fact(FoodFromTheMenu="ChickenPotPie"))
    def action28(self):
        for x in ChickenPotPie.items():
            print (x[1],'\t',x[0])
            
    @Rule(Fact(start="true"),Fact(FoodFromTheMenu="LasagnaWithMeat"))
    def action29(self):
        for x in LasagnaWithMeat.items():
            print (x[1],'\t',x[0])
            
    @Rule(Fact(start="true"),Fact(FoodFromTheMenu="Lamb"))
    def action30(self):
        for x in Lamb.items():
            print (x[1],'\t',x[0])
            
    @Rule(Fact(start="true"),Fact(FoodFromTheMenu="LambKebab"))
    def action31(self):
        for x in LambKebab.items():
            print (x[1],'\t',x[0])
            
    @Rule(Fact(start="true"),Fact(FoodFromTheMenu="KeyLimePie"))
    def action32(self):
        for x in KeyLimePie.items():
            print (x[1],'\t',x[0])
            
    @Rule(Fact(start="true"),Fact(FoodFromTheMenu="TraditionalDonut"))
    def action33(self):
        for x in TraditionalDonut.items():
            print (x[1],'\t',x[0]) 
            
    @Rule(Fact(start="true"),Fact(FoodFromTheMenu="PitaBread"))
    def action34(self):
        for x in PitaBread.items():
            print (x[1],'\t',x[0])  
            
    @Rule(Fact(start="true"),Fact(FoodFromTheMenu="Kasha"))
    def action35(self):
        for x in Kasha.items():
            print (x[1],'\t',x[0])
               
    @Rule(Fact(start="true"),Fact(FoodFromTheMenu="BeefShishKabobWithVegetables"))
    def action36(self):
        for x in BeefShishKabobWithVegetables.items():
            print (x[1],'\t',x[0])
         
    @Rule(Fact(start="true"),Fact(FoodFromTheMenu="RicePilaf"))
    def action37(self):
        for x in RicePilaf.items():
            print (x[1],'\t',x[0])
         
    @Rule(Fact(start="true"),Fact(FoodFromTheMenu="Premium6GrainRice"))
    def action38(self):
        for x in Premium6GrainRice.items():
            print (x[1],'\t',x[0])
         
    @Rule(Fact(start="true"),Fact(FoodFromTheMenu="PorkKabanos"))
    def action39(self):
        for x in PorkKabanos.items():
            print (x[1],'\t',x[0])
         
    @Rule(Fact(start="true"),Fact(FoodFromTheMenu="OrganicRawKombucha"))
    def action40(self):
        for x in OrganicRawKombucha.items():
            print (x[1],'\t',x[0])
    
    @Rule(Fact(start="true"),Fact(FoodFromTheMenu="PacificKombu"))
    def action41(self):
        for x in PacificKombu.items():
            print (x[1],'\t',x[0])  
            
            
    @Rule(Fact(start="true"),Fact(FoodFromTheMenu="MozzarellaSticks"))
    def action42(self):
        for x in MozzarellaSticks.items():
            print (x[1],'\t',x[0]) 
            
    @Rule(Fact(start="true"),Fact(FoodFromTheMenu="Monkfish"))
    def action43(self):
        for x in Monkfish.items():
            print (x[1],'\t',x[0]) 
            
    @Rule(Fact(start="true"),Fact(FoodFromTheMenu="MongolianBeef"))
    def action44(self):
        for x in MongolianBeef.items():
            print (x[1],'\t',x[0]) 
            
            
    @Rule(Fact(start="true"),Fact(FoodFromTheMenu="MontrealSmokedMeat"))
    def action45(self):
        for x in MontrealSmokedMeat.items():
            print (x[1],'\t',x[0])          
            
    @Rule(Fact(start="true"),Fact(FoodFromTheMenu="MacaroniOrNoodlesWithCheese"))
    def action46(self):
        for x in MacaroniOrNoodlesWithCheese.items():
            print (x[1],'\t',x[0]) 
      
    @Rule(Fact(start="true"),NOT(Fact(disease=W())))
    def enter_disease(self):
        self.declare(input("enter what the desease you are suffering from"))

# %%
ED = ExpertDiet()

# %%
ED.reset()

# %%
ED.facts
# Out:
# FactList([(0, InitialFact()),
#           (1, Fact(start='true')),
#           (2,
#            food('StrawberryCheesecake', 'ChickenBiryani', 'ChickenGyroSandwich', 'GyroSandwich', 'LambGyroSandwich', 'LadooRoundBall', 'LemonMeringuePie', 'UdonNoodles', 'ItalianBeef', 'OrganicYellowPopCorn', 'RedVelvetCake', 'ChickenBreast', 'ApplePie', 'Bacon', 'Hummus', 'Tiramisu', 'Okonomiyaki', 'OrangeSoda', 'FalafelPitaSandwich', 'GrilledCheeseSandwich', 'Guacamole', 'EmuDrum', 'CrackerMix', 'Bhatura', 'HuevosRancheros', 'BananaCakeWithIcing', 'ChickenPotPie', 'LasagnaWithMeat', 'Lamb', 'LambKebab', 'KeyLimePie', 'TraditionalDonut', 'PitaBread', 'Kasha', 'BeefShishKabobWithVegetables', 'RicePilaf', 'Premium6GrainRice', 'PorkKabanos', 'OrganicRawKombucha', 'PacificKombu', 'MozzarellaSticks', 'Monkfish', 'MongolianBeef', 'MontrealSmokedMeat', 'MacaroniOrNoodlesWithCheese'))])

# %%
ED.run()
# Out:
# please , Choose food from the menu *_*   ApplePie
# Are You Suffering From Disease  yes
# What's the disease you suffering from obesity
# 411 	 Calories
# 2.09 	 Fat
# 57.5 	 Carbs
# 3.72 	 Protein
# 0 	 Cholesterol
# 0.327 	 Sodium
# 0.011 	 Calcium
# 0.00174 	 Iron
# 0.122 	 Potassium
# 1.7e-05 	 VitaminA
# 0.0026 	 VitaminC
